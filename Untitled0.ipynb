# %% [markdown]
# <a href="https://colab.research.google.com/github/omarali024/Student-Organizations-Website/blob/Seif-Amr/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
u=np.array([1,2])
v=np.array([4,-2])
w=np.array([-3,5])
print(u+w)
# Out:
# [-2  7]

# %%
print(2*u+3*v-w)
# Out:
# [17 -7]

# %%
x= np.array([-1,2,3])
print(3*x)
y= np.array([-1,2,3,-2])
print(4*y)
z= np.array([1,-4,3,-2,5])
print(-5*z)
# Out:
# [-3  6  9]
# [-4  8 12 -8]
# [ -5  20 -15  10 -25]

# %%
u = np.array([2,1])
v = np.array([3,4])
print(np.dot(u,v))
u = np.array([7,1,2,-4])
v = np.array([3,0,-1,5])
print(np.dot(u,v))
# Out:
# 10
# -1

# %%
u= np.array([4,-2,1,3])
print(np.linalg.norm(u))
# Out:
# 5.477225575051661

# %%
u= np.array([4,1,1])
um=np.linalg.norm(u)
print(u/um)
print(np.linalg.norm(u/um))
# Out:
# [0.94280904 0.23570226 0.23570226]
# 1.0
